# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")
tmdb_access_key = os.getenv("TMDB_ACCESS_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"

filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = f"{url}api-key={nyt_api_key}&fq={filter_query}&begin_date={begin_date}&end_date={end_date}&sort={sort}&fl={field_list}"

print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=Ab7tjs5wfqjJJtfsDF3MU6G3lef0HW3O&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&begin_date=20130101&end_date=20230531&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(0, 19):
    # create query with a page number
    # API results show 10 articles at a time
    page_query_url = f"{query_url}&page={str(page)}"
        
    # Make a "GET" request and retrieve the JSON
    articles = requests.get(page_query_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for article in articles["response"]["docs"]:
            reviews_list.append(article)
        # Print the page that was just retrieved
            print(f"Preview of Review: {article['snippet']}")

        # Print the page number that had no results then break from the loop
    except:
        print(f"Page {page} has no results.")
        break
# Out:
# Preview of Review: A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.
# Preview of Review: Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.
# Preview of Review: Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.
# Preview of Review: Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.
# Preview of Review: A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone’s lives.
# Preview of Review: A film adaptation of Taylor Jenkins Reid’s novel has potential for drama, but it stumbles on stock melodrama.
# Preview of Review: There’s not much Lennon music heard in this doc about his affair with May Pang, and given how much Pang trashes his wife, Yoko Ono, it’s no surprise it was withheld.
# Preview of Review: A mesmerizing Teyana Taylor stars in A.V. Rockwell’s feature directing debut, about motherhood and survival in a fast-changing city.
# Preview of Review: This humdrum Netflix romantic comedy features Reese Witherspoon and Ashton Kutcher as longtime friends with possibly hidden feelings for each other.
# Preview of Review: To combat the overdose crisis, a group that includes former and current users open a safe consumption site where shooting up does not have to mean death.
# Preview of Review: This documentary from Ryan White rewinds, to powerful effect, on Pamela Anderson’s life and fame.
# Preview of Review: In Matt Carter’s gay rugby film, sports and romance smash together like two players from opposing teams.
# Preview of Review: In this intelligent melodrama by the director Aleem Khan, a British woman discovers her husband has been leading a double life.
# Preview of Review: In this naturalistic drama from Spain, a family confronts the impending loss of its generations-old farm.
# Preview of Review: A family archive provides intimate records of a love affair that began between two women imprisoned in the Ravensbrück concentration camp.
# Preview of Review: The new Netflix adaptation of D.H. Lawrence’s once-controversial novel is both steamy and decorous.
# Preview of Review: A young singer gets more than she bargained for when she accepts a job as a nanny for a billionaire’s children.
# Preview of Review: Elegance Bratton’s autobiographical first feature is a lyrical, wrenching look at a young Marine’s journey through basic training.
# Preview of Review: Luca Guadagnino’s latest stars Timothée Chalamet and Taylor Russell as young cannibals on the run.
# Preview of Review: A schoolteacher, her police officer husband and his lover deny each other romantic satisfaction in this dismal melodrama.
# Preview of Review: Thomas Mann’s beguiling performance drives this Emma Roberts vehicle, but the romantic comedy creaks under the weight of its coincidences.
# Preview of Review: Set in Paris in the 1960s, the film tells the story of two irrepressible lovers, and their young son, whose tale turns tragic.
# Preview of Review: This comedy is a daddy-issues movie with a queasy premise truly made for these times.
# Preview of Review: Two former childhood friends rekindle their connection in this sweetly hopeful story of romantic longing.
# Preview of Review: Katie Holmes writes, directs and stars in this minor-key rom-com set in 2020.
# Preview of Review: A disillusioned college professor develops a relationship with a young Chinese woman, in a familiar and worn-out narrative.
# Preview of Review: Twenty-five years after they split, two former high school sweethearts reluctantly reunite for an awkward night.
# Preview of Review: A couple break up, but remain together, frustratingly, because of the husband’s financial woes.
# Preview of Review: In war-torn Liberia, Charlize Theron and Javier Bardem face a big problem: how to keep their knotty relationship from fizzling.
# Preview of Review: In Ingrid Jungermann’s droll comedy, ex-lovers who produce a podcast about serial killers find themselves at odds when a new romantic interest emerges.
# Preview of Review: Isabelle Huppert and Louis Garrel star in a screen version of an 18th-century Marivaux play and the last film directed by Luc Bondy.
# Preview of Review: In “My Journey Through French Cinema,” Mr. Tavernier’s documentary about movies doubles as an autobiography.
# Preview of Review: Kumail Nanjiani stars opposite Zoe Kazan in this very funny, moving true story about how he found and almost lost love. Holly Hunter and Ray Romano also star.
# Preview of Review: The filmmakers Fiona Gordon and Dominique Abel star in their fourth movie, a tale infused with physical comedy about a woman in search of her aunt.
# Preview of Review: This combination crime drama and romance finds Emile Hirsch and Zoë Kravitz circling each other, and trying to stay away from bad guys.
# Preview of Review: Amandla Stenberg plays a teenager with an immune system disorder who falls for the boy next door, and risks everything.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
nyt_top5_preview = []
for top5 in range(0, 4):
    article = reviews_list[top5]
    nyt_top5_preview.append(article)
json_top5 = json.dumps(nyt_top5_preview, indent=4)
print(json_top5)
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_list_df = pd.json_normalize(reviews_list)

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early

reviews_list_df["title"] = reviews_list_df["headline.main"].apply( lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")] )

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_list_df["keywords"]= reviews_list_df["keywords"].apply(extract_keywords)

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
title_list = reviews_list_df["title"].to_list()

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key
headers = {
    "accept": "application/json",
    "Authorization": "Bearer " + tmdb_access_key
}

# %%
# Create an empty list to store the results
movie_list = []
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1


# Loop through the titles
for title in title_list:
    
    # Check if we need to sleep before making a request
    if request_counter == 50:
        time.sleep(1)
        request_counter = 1
        print("Application is sleeping.")

    # Add 1 to the request counter
    else:
        request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    request_url = url + title
    response_data = requests.get(request_url, headers=headers)
    data = response_data.json()
    

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    
    # empty string and lists
    movie_id = ""
    genre_names = []
    spoken_languages = []
    production_countries_list = []
    details_response = ""
    try:
        # Get movie id
        # tmdb_movies_list = title_list
        movie_id = str(data["results"][0]["id"])
        

    except IndexError:
        print("IndexError; Movie id was not found for " + title )
        

    except:
        print("title not found: " + title)
        pass

    try:
        details_url = "https://api.themoviedb.org/3/movie/" + movie_id

        # Execute "GET" request with url
        details_data = requests.get(details_url, headers=headers)
        details_response = details_data.json()
        
        
        # Extract the genre names into a list
        genres = details_response["genres"]
        
        
        for genre in genres:
            genre_names.append(genre["name"])
        
        
    except IndexError:
        print("IndexError; Movie details or genres not found " + title )
        pass

    except:
        print("title not found: " + title)
        pass

    try:
        # Extract the spoken_languages' English name into a list
        languages = details_response["spoken_languages"]
        
        for language in languages:
            spoken_languages.append(language["english_name"])
        

    except IndexError:
        print("IndexError; spoken languages not found " + title )
        break

    except:
        print("Lanaguage -- title not found: " + title)
        pass

    try:

        # Extract the production_countries' name into a list
        production_countries = details_response["production_countries"]
        
        for production_country in production_countries:
            production_countries_list.append(production_country["name"])
        

    except IndexError:
        print("IndexError; production countries not found for " + title )
        

    except:
        print("Production -- title not found: " + title)
        pass  

    try:

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        tmdb_movies_dict = {}
        tmdb_movies_dict = {"movie_id": movie_id, "title": title, "genres":genre_names, "languages":spoken_languages, "production_country": production_countries_list}
        tmdb_movies_list.append(tmdb_movies_dict)

        # Print out the title that was found
        print("Found Movie: " + title)

    except IndexError:
        print("IndexError; Movie details not found " + title )
        pass

    except:
        print("Title not found: " + title)
        pass
# Out:
# Found Movie: The Attachment Diaries
# IndexError; Movie id was not found for What’s Love Got to Do With It?’ Probably a Lo
# title not found: What’s Love Got to Do With It?’ Probably a Lo
# Lanaguage -- title not found: What’s Love Got to Do With It?’ Probably a Lo
# Production -- title not found: What’s Love Got to Do With It?’ Probably a Lo
# Found Movie: What’s Love Got to Do With It?’ Probably a Lo
# Found Movie: You Can Live Forever
# Found Movie: A Tourist’s Guide to Love
# Found Movie: Other People’s Children
# Found Movie: One True Loves
# Found Movie: The Lost Weekend: A Love Story
# Found Movie: A Thousand and One
# Found Movie: Your Place or Mine
# Found Movie: Love in the Time of Fentanyl
# Found Movie: Pamela, a Love Story
# Found Movie: In From the Side
# Found Movie: After Love
# Found Movie: Alcarràs
# Found Movie: Nelly & Nadine
# Found Movie: Lady Chatterley’s Lover
# Found Movie: The Sound of Christmas
# Found Movie: The Inspection
# Found Movie: Bones and All
# Found Movie: My Policeman
# Found Movie: About Fate
# Found Movie: Waiting for Bojangles
# Found Movie: I Love My Dad
# Found Movie: A Love Song
# Found Movie: Alone Together
# Found Movie: Art of Love
# Found Movie: The Wheel
# Found Movie: Thor: Love and Thunder
# Found Movie: Both Sides of the Blade
# Found Movie: Fire of Love
# Found Movie: Love & Gelato
# Found Movie: Stay Prayed Up
# Found Movie: Benediction
# Found Movie: Dinner in America
# Found Movie: In a New York Minute
# Found Movie: Anaïs in Love
# Found Movie: I Love America
# Found Movie: See You Then
# Found Movie: La Mami
# Found Movie: Love After Love
# Found Movie: Deep Water
# Found Movie: Lucy and Desi
# Found Movie: Cyrano
# Found Movie: The In Between
# Found Movie: Book of Love
# Found Movie: Lingui, the Sacred Bonds
# Found Movie: The Pink Cloud
# Found Movie: A Journal for Jordan
# Found Movie: West Side Story
# Application is sleeping.
# IndexError; Movie id was not found for Aulcie
# title not found: Aulcie
# Lanaguage -- title not found: Aulcie
# Production -- title not found: Aulcie
# Found Movie: Aulcie
# Found Movie: Love Is Love Is Love
# Found Movie: Love Hard
# Found Movie: Bergman Island
# Found Movie: Hard Luck Love Song
# Found Movie: South of Heaven
# Found Movie: Wife of a Spy
# Found Movie: Happier Than Ever
# Found Movie: Together
# Found Movie: Annette
# Found Movie: Resort to Love
# Found Movie: Woodstock 99: Peace, Love and Rage
# Found Movie: Casanova, Last Love
# Found Movie: Running Against the Wind
# Found Movie: Asia
# Found Movie: Undine
# Found Movie: This Town
# Found Movie: Tu Me Manques
# Found Movie: Monday
# Found Movie: Ride or Die
# Found Movie: Future People
# Found Movie: Luz
# Found Movie: Happily
# Found Movie: This Is the Life
# Found Movie: To All the Boys: Always and Forever
# Found Movie: Young Hearts
# Found Movie: Little Fish
# Found Movie: Two of Us
# Found Movie: Atlantis
# Found Movie: Preparations to Be Together
# Found Movie: Your Name Engraved Herein
# Found Movie: Sylvie’s Love
# Found Movie: Ariana Grande: Excuse Me, I Love You
# Found Movie: Museum Town
# Found Movie: Wild Mountain Thyme
# Found Movie: My Psychedelic Love Story
# Found Movie: 69: The Saga of Danny Hernandez
# Found Movie: Ammonite
# Found Movie: Love and Monsters
# Found Movie: Dick Johnson Is Dead
# Found Movie: Love, Guaranteed
# Found Movie: Feel the Beat
# Found Movie: Babyteeth
# Found Movie: Spelling the Dream
# Found Movie: A Secret Love
# Found Movie: Love Wedding Repeat
# Found Movie: Almost Love
# Found Movie: Hope Gap
# Found Movie: All the Bright Places
# Found Movie: The Photograph
# Application is sleeping.
# Found Movie: You Go to My Head
# Found Movie: Ordinary Love
# Found Movie: To All the Boys: P.S. I Still Love You
# Found Movie: The Woman Who Loves Giraffes
# Found Movie: Queen & Slim
# Found Movie: Marriage Story
# Found Movie: Cyrano, My Love
# Found Movie: Pretenders
# Found Movie: First Love
# Found Movie: Loro
# Found Movie: Falling Inn Love
# Found Movie: Hot Air
# Found Movie: Love, Antosha
# Found Movie: Leto
# Found Movie: The Tomorrow Man
# Found Movie: Asako I & II
# Found Movie: The Sun Is Also a Star
# Found Movie: Shéhérazade
# Found Movie: Long Shot
# Found Movie: Clara
# Found Movie: Kalank
# Found Movie: Rafiki
# Found Movie: Diane
# Found Movie: Five Feet Apart
# Found Movie: Ash Is Purest White
# Found Movie: Gloria Bell
# Found Movie: Black Mother
# Found Movie: The Hole in the Ground
# Found Movie: How to Train Your Dragon: The Hidden World
# Found Movie: A Tuba to Cuba
# Found Movie: Fighting With My Family
# Found Movie: Sorry Angel
# Found Movie: Berlin, I Love You
# Found Movie: Untogether
# Found Movie: Cold War
# Found Movie: If Beale Street Could Talk
# Found Movie: Asher
# Found Movie: The Party’s Just Beginning
# Found Movie: The Great Pretender
# Found Movie: Sicilian Ghost Story
# Found Movie: The New Romantic
# Found Movie: Pimp
# Found Movie: In a Relationship
# IndexError; Movie id was not found for They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# title not found: They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# Lanaguage -- title not found: They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# Production -- title not found: They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# Found Movie: They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil
# IndexError; Movie id was not found for Burning,’ Love Ignites a Divided Worl
# title not found: Burning,’ Love Ignites a Divided Worl
# Lanaguage -- title not found: Burning,’ Love Ignites a Divided Worl
# Production -- title not found: Burning,’ Love Ignites a Divided Worl
# Found Movie: Burning,’ Love Ignites a Divided Worl
# IndexError; Movie id was not found for After Everything,’ a Young Love Blooms in Crisi
# title not found: After Everything,’ a Young Love Blooms in Crisi
# Lanaguage -- title not found: After Everything,’ a Young Love Blooms in Crisi
# Production -- title not found: After Everything,’ a Young Love Blooms in Crisi
# Found Movie: After Everything,’ a Young Love Blooms in Crisi
# IndexError; Movie id was not found for Quincy’ Captures a Lifelong Love Affair With Musi
# title not found: Quincy’ Captures a Lifelong Love Affair With Musi
# Lanaguage -- title not found: Quincy’ Captures a Lifelong Love Affair With Musi
# Production -- title not found: Quincy’ Captures a Lifelong Love Affair With Musi
# Found Movie: Quincy’ Captures a Lifelong Love Affair With Musi
# IndexError; Movie id was not found for Love, Gilda,’ a Portrait of a Brief and Brilliant Caree
# title not found: Love, Gilda,’ a Portrait of a Brief and Brilliant Caree
# Lanaguage -- title not found: Love, Gilda,’ a Portrait of a Brief and Brilliant Caree
# Production -- title not found: Love, Gilda,’ a Portrait of a Brief and Brilliant Caree
# Found Movie: Love, Gilda,’ a Portrait of a Brief and Brilliant Caree
# IndexError; Movie id was not found for Tea With the Dames,’ Four Legends Dish on Acting and Lov
# title not found: Tea With the Dames,’ Four Legends Dish on Acting and Lov
# Lanaguage -- title not found: Tea With the Dames,’ Four Legends Dish on Acting and Lov
# Production -- title not found: Tea With the Dames,’ Four Legends Dish on Acting and Lov
# Found Movie: Tea With the Dames,’ Four Legends Dish on Acting and Lov
# IndexError; Movie id was not found for Bel Canto,’ Music Is the Food of Love and Rebellio
# title not found: Bel Canto,’ Music Is the Food of Love and Rebellio
# Lanaguage -- title not found: Bel Canto,’ Music Is the Food of Love and Rebellio
# Production -- title not found: Bel Canto,’ Music Is the Food of Love and Rebellio
# Found Movie: Bel Canto,’ Music Is the Food of Love and Rebellio
# Application is sleeping.
# IndexError; Movie id was not found for The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov
# title not found: The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov
# Lanaguage -- title not found: The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov
# Production -- title not found: The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov
# Found Movie: The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov
# IndexError; Movie id was not found for Love, Cecil,’ an Aesthete Ahead of His Tim
# title not found: Love, Cecil,’ an Aesthete Ahead of His Tim
# Lanaguage -- title not found: Love, Cecil,’ an Aesthete Ahead of His Tim
# Production -- title not found: Love, Cecil,’ an Aesthete Ahead of His Tim
# Found Movie: Love, Cecil,’ an Aesthete Ahead of His Tim
# Found Movie: How to Talk to Girls at Parties
# IndexError; Movie id was not found for Rogers Park,’ Life and Love in a Chicago Neighborhoo
# title not found: Rogers Park,’ Life and Love in a Chicago Neighborhoo
# Lanaguage -- title not found: Rogers Park,’ Life and Love in a Chicago Neighborhoo
# Production -- title not found: Rogers Park,’ Life and Love in a Chicago Neighborhoo
# Found Movie: Rogers Park,’ Life and Love in a Chicago Neighborhoo
# Found Movie: Love & Bananas,’ Uncovering the Plight of the Asian Elephan
# Found Movie: Godard Mon Amour
# IndexError; Movie id was not found for Submergence,’ a Love Story Sunk by Geopolitic
# title not found: Submergence,’ a Love Story Sunk by Geopolitic
# Lanaguage -- title not found: Submergence,’ a Love Story Sunk by Geopolitic
# Production -- title not found: Submergence,’ a Love Story Sunk by Geopolitic
# Found Movie: Submergence,’ a Love Story Sunk by Geopolitic
# IndexError; Movie id was not found for Love After Love,’ an Unflinching Look at Extended Grie
# title not found: Love After Love,’ an Unflinching Look at Extended Grie
# Lanaguage -- title not found: Love After Love,’ an Unflinching Look at Extended Grie
# Production -- title not found: Love After Love,’ an Unflinching Look at Extended Grie
# Found Movie: Love After Love,’ an Unflinching Look at Extended Grie
# Found Movie: Outside In
# IndexError; Movie id was not found for Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre
# title not found: Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre
# Lanaguage -- title not found: Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre
# Production -- title not found: Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre
# Found Movie: Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre
# IndexError; Movie id was not found for Keep the Change,’ Two People With Autism Find Lov
# title not found: Keep the Change,’ Two People With Autism Find Lov
# Lanaguage -- title not found: Keep the Change,’ Two People With Autism Find Lov
# Production -- title not found: Keep the Change,’ Two People With Autism Find Lov
# Found Movie: Keep the Change,’ Two People With Autism Find Lov
# Found Movie: The Party
# IndexError; Movie id was not found for The Housemaid,’ Twisted Love and Angry Ghosts in Vietna
# title not found: The Housemaid,’ Twisted Love and Angry Ghosts in Vietna
# Lanaguage -- title not found: The Housemaid,’ Twisted Love and Angry Ghosts in Vietna
# Production -- title not found: The Housemaid,’ Twisted Love and Angry Ghosts in Vietna
# Found Movie: The Housemaid,’ Twisted Love and Angry Ghosts in Vietna
# IndexError; Movie id was not found for Forever My Girl,’ a Romance Resumes After a Long Brea
# title not found: Forever My Girl,’ a Romance Resumes After a Long Brea
# Lanaguage -- title not found: Forever My Girl,’ a Romance Resumes After a Long Brea
# Production -- title not found: Forever My Girl,’ a Romance Resumes After a Long Brea
# Found Movie: Forever My Girl,’ a Romance Resumes After a Long Brea
# IndexError; Movie id was not found for Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# title not found: Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# Lanaguage -- title not found: Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# Production -- title not found: Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# Found Movie: Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr
# Found Movie: Lover for a Day
# IndexError; Movie id was not found for Youth,’ the People’s Dance Troupe, in Love and Wa
# title not found: Youth,’ the People’s Dance Troupe, in Love and Wa
# Lanaguage -- title not found: Youth,’ the People’s Dance Troupe, in Love and Wa
# Production -- title not found: Youth,’ the People’s Dance Troupe, in Love and Wa
# Found Movie: Youth,’ the People’s Dance Troupe, in Love and Wa
# IndexError; Movie id was not found for Killing for Love’ Revisits a Virginia Murder Cas
# title not found: Killing for Love’ Revisits a Virginia Murder Cas
# Lanaguage -- title not found: Killing for Love’ Revisits a Virginia Murder Cas
# Production -- title not found: Killing for Love’ Revisits a Virginia Murder Cas
# Found Movie: Killing for Love’ Revisits a Virginia Murder Cas
# IndexError; Movie id was not found for The Shape of Water’ Is Altogether Wonderfu
# title not found: The Shape of Water’ Is Altogether Wonderfu
# Lanaguage -- title not found: The Shape of Water’ Is Altogether Wonderfu
# Production -- title not found: The Shape of Water’ Is Altogether Wonderfu
# Found Movie: The Shape of Water’ Is Altogether Wonderfu
# IndexError; Movie id was not found for Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr
# title not found: Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr
# Lanaguage -- title not found: Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr
# Production -- title not found: Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr
# Found Movie: Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr
# IndexError; Movie id was not found for Cuba and the Cameraman’ Lavishes Love on a Country … and Castr
# title not found: Cuba and the Cameraman’ Lavishes Love on a Country … and Castr
# Lanaguage -- title not found: Cuba and the Cameraman’ Lavishes Love on a Country … and Castr
# Production -- title not found: Cuba and the Cameraman’ Lavishes Love on a Country … and Castr
# Found Movie: Cuba and the Cameraman’ Lavishes Love on a Country … and Castr
# IndexError; Movie id was not found for On the Beach at Night Alone’ Zooms in on a Love Affai
# title not found: On the Beach at Night Alone’ Zooms in on a Love Affai
# Lanaguage -- title not found: On the Beach at Night Alone’ Zooms in on a Love Affai
# Production -- title not found: On the Beach at Night Alone’ Zooms in on a Love Affai
# Found Movie: On the Beach at Night Alone’ Zooms in on a Love Affai
# IndexError; Movie id was not found for Thelma,’ a Woman in Love Can Burn Down the Worl
# title not found: Thelma,’ a Woman in Love Can Burn Down the Worl
# Lanaguage -- title not found: Thelma,’ a Woman in Love Can Burn Down the Worl
# Production -- title not found: Thelma,’ a Woman in Love Can Burn Down the Worl
# Found Movie: Thelma,’ a Woman in Love Can Burn Down the Worl
# IndexError; Movie id was not found for Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade
# title not found: Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade
# Lanaguage -- title not found: Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade
# Production -- title not found: Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade
# Found Movie: Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade
# IndexError; Movie id was not found for It Happened in L.A.,’ All That Questing After Lov
# title not found: It Happened in L.A.,’ All That Questing After Lov
# Lanaguage -- title not found: It Happened in L.A.,’ All That Questing After Lov
# Production -- title not found: It Happened in L.A.,’ All That Questing After Lov
# Found Movie: It Happened in L.A.,’ All That Questing After Lov
# Found Movie: God’s Own Country
# Found Movie: The Mountain Between Us
# IndexError; Movie id was not found for Dina,’ a Differently Abled Love Stor
# title not found: Dina,’ a Differently Abled Love Stor
# Lanaguage -- title not found: Dina,’ a Differently Abled Love Stor
# Production -- title not found: Dina,’ a Differently Abled Love Stor
# Found Movie: Dina,’ a Differently Abled Love Stor
# Found Movie: In Search of Fellini
# IndexError; Movie id was not found for Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# title not found: Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# Lanaguage -- title not found: Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# Production -- title not found: Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# Found Movie: Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen
# IndexError; Movie id was not found for I Do ... Until I Don’t,’ Love and Loathing in Florid
# title not found: I Do ... Until I Don’t,’ Love and Loathing in Florid
# Lanaguage -- title not found: I Do ... Until I Don’t,’ Love and Loathing in Florid
# Production -- title not found: I Do ... Until I Don’t,’ Love and Loathing in Florid
# Found Movie: I Do ... Until I Don’t,’ Love and Loathing in Florid
# IndexError; Movie id was not found for Tales of an Immoral Couple’: Love Means Having to Grow U
# title not found: Tales of an Immoral Couple’: Love Means Having to Grow U
# Lanaguage -- title not found: Tales of an Immoral Couple’: Love Means Having to Grow U
# Production -- title not found: Tales of an Immoral Couple’: Love Means Having to Grow U
# Found Movie: Tales of an Immoral Couple’: Love Means Having to Grow U
# IndexError; Movie id was not found for After Love’ and Regretting Every Momen
# title not found: After Love’ and Regretting Every Momen
# Lanaguage -- title not found: After Love’ and Regretting Every Momen
# Production -- title not found: After Love’ and Regretting Every Momen
# Found Movie: After Love’ and Regretting Every Momen
# Found Movie: The Last Face
# IndexError; Movie id was not found for Women Who Kill,’ and May Be in Love With On
# title not found: Women Who Kill,’ and May Be in Love With On
# Lanaguage -- title not found: Women Who Kill,’ and May Be in Love With On
# Production -- title not found: Women Who Kill,’ and May Be in Love With On
# Found Movie: Women Who Kill,’ and May Be in Love With On
# IndexError; Movie id was not found for False Confessions,’ the Play’s Not Quite the Thin
# title not found: False Confessions,’ the Play’s Not Quite the Thin
# Lanaguage -- title not found: False Confessions,’ the Play’s Not Quite the Thin
# Production -- title not found: False Confessions,’ the Play’s Not Quite the Thin
# Found Movie: False Confessions,’ the Play’s Not Quite the Thin
# IndexError; Movie id was not found for Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# title not found: Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# Lanaguage -- title not found: Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# Production -- title not found: Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# Found Movie: Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem
# IndexError; Movie id was not found for The Big Sick,’ Comedy Is Hard, Love Harde
# title not found: The Big Sick,’ Comedy Is Hard, Love Harde
# Lanaguage -- title not found: The Big Sick,’ Comedy Is Hard, Love Harde
# Production -- title not found: The Big Sick,’ Comedy Is Hard, Love Harde
# Found Movie: The Big Sick,’ Comedy Is Hard, Love Harde
# Found Movie: Lost in Paris
# IndexError; Movie id was not found for Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# title not found: Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# Lanaguage -- title not found: Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# Production -- title not found: Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# Found Movie: Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# IndexError; Movie id was not found for Everything, Everything’ Pits Love Against Diseas
# title not found: Everything, Everything’ Pits Love Against Diseas
# Lanaguage -- title not found: Everything, Everything’ Pits Love Against Diseas
# Production -- title not found: Everything, Everything’ Pits Love Against Diseas
# Found Movie: Everything, Everything’ Pits Love Against Diseas

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

movie_top5_preview = []
for top5 in range(0, 4):
    title = tmdb_movies_list[top5]

    movie_top5_preview.append(title)
json_top5 = json.dumps(movie_top5_preview, indent=4)
print(json_top5)
# Out:
# [
#     {
#         "movie_id": "743040",
#         "title": "The Attachment Diaries",
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "languages": [
#             "Spanish"
#         ],
#         "production_country": [
#             "Argentina"
#         ]
#     },
#     {
#         "movie_id": "",
#         "title": "What\u2019s Love Got to Do With It?\u2019 Probably a Lo",
#         "genres": [],
#         "languages": [],
#         "production_country": []
#     },
#     {
#         "movie_id": "887580",
#         "title": "You Can Live Forever",
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "languages": [
#             "English",
#             "French"
#         ],
#         "production_country": [
#             "Canada",
#             "United States of America"
#         ]
#     },
#     {
#         "movie_id": "813726",
#         "title": "A Tourist\u2019s Guide to Love",
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "languages": [
#             "English",
#             "Vietnamese"
#         ],
#         "production_country": [
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_movies_df= pd.json_normalize(tmdb_movies_list)

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
combined_df = pd.merge(reviews_list_df, tmdb_movies_df, on= "title", how="inner")

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_tofix = ["genres", "languages", "production_country", "headline.main", "byline.person"]


# Create a list of characters to remove
replacements = ["[", "]", "{", "}"]

# Loop through the list of columns to fix
for column in columns_tofix:
    
    combined_df
    # Convert the column to type 'str'
    combined_df[column] = combined_df[column].astype(str)
    
    
    # Loop through characters to remove
    for char in replacements:
        combined_df[column] = combined_df[column].str.replace(char, "")
        
            

# Display the fixed DataFrame
combined_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 185  https://www.nytimes.com/2017/06/22/movies/my-j...
# 186  https://www.nytimes.com/2017/06/22/movies/the-...
# 187  https://www.nytimes.com/2017/06/15/movies/lost...
# 188  https://www.nytimes.com/2017/06/01/movies/vinc...
# 189  https://www.nytimes.com/2017/05/18/movies/ever...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 185  In “My Journey Through French Cinema,” Mr. Tav...  The New York Times
# 186  Kumail Nanjiani stars opposite Zoe Kazan in th...  The New York Times
# 187  The filmmakers Fiona Gordon and Dominique Abel...  The New York Times
# 188  This combination crime drama and romance finds...  The New York Times
# 189  Amandla Stenberg plays a teenager with an immu...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 185  subject: Documentary Films and Programs;person...
# 186  subject: Movies;creative_works: The Big Sick (...
# 187  creative_works: Lost in Paris (Movie);subject:...
# 188  subject: Movies;creative_works: Vincent N Roxx...
# 189  subject: Movies;creative_works: Everything, Ev...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 185  2017-06-22T21:14:56+0000         773
# 186  2017-06-22T09:00:31+0000        1073
# 187  2017-06-15T19:37:09+0000         254
# 188  2017-06-01T19:52:51+0000         287
# 189  2017-05-18T21:02:53+0000         270
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 185  Review: Those Movies, Himself — Bertrand Taver...            None
# 186  Review: In ‘The Big Sick,’ Comedy Is Hard, Lov...            None
# 187  Review: Finding Love (and Slapstick) While ‘Lo...            None
# 188  Review: In ‘Vincent N Roxxy,’ Love Is in the A...            None
# 189  Review: ‘Everything, Everything’ Pits Love Aga...            None
#
#     headline.content_kicker                 headline.print_headline  ...  \
# 0                      None                  The Attachment Diaries  ...
# 1                      None          What’s Love Got to Do With It?  ...
# 2                      None                    You Can Live Forever  ...
# 3                      None              A Tourist’s  Guide to Love  ...
# 4                      None  Intoxicating Love With a Sobering Turn  ...
# ..                      ...                                     ...  ...
# 185                    None           Reflecting on a Lifelong Love  ...
# 186                    None                 Love and (Almost) Death  ...
# 187                    None                           Lost in Paris  ...
# 188                    None                         Vincent N Roxxy  ...
# 189                    None                  Everything, Everything  ...
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 185         None         None         By Manohla Dargis
# 186         None         None         By Manohla Dargis
# 187         None         None         By Ben Kenigsberg
# 188         None         None         By Ken Jaworowski
# 189         None         None        By Neil Genzlinger
#
#                                          byline.person byline.organization  \
# 0    'firstname': 'Jeannette', 'middlename': None, ...                None
# 1    'firstname': 'Jeannette', 'middlename': None, ...                None
# 2    'firstname': 'Elisabeth', 'middlename': None, ...                None
# 3    'firstname': 'Elisabeth', 'middlename': None, ...                None
# 4    'firstname': 'Manohla', 'middlename': None, 'l...                None
# ..                                                 ...                 ...
# 185  'firstname': 'Manohla', 'middlename': None, 'l...                None
# 186  'firstname': 'Manohla', 'middlename': None, 'l...                None
# 187  'firstname': 'Ben', 'middlename': None, 'lastn...                None
# 188  'firstname': 'Ken', 'middlename': None, 'lastn...                None
# 189  'firstname': 'Neil', 'middlename': None, 'last...                None
#
#                                                  title movie_id  \
# 0                               The Attachment Diaries   743040
# 1        What’s Love Got to Do With It?’ Probably a Lo
# 2                                 You Can Live Forever   887580
# 3                            A Tourist’s Guide to Love   813726
# 4                              Other People’s Children   803694
# ..                                                 ...      ...
# 185  Review: Those Movies, Himself — Bertrand Taver...
# 186          The Big Sick,’ Comedy Is Hard, Love Harde
# 187                                      Lost in Paris   413778
# 188  Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# 189   Everything, Everything’ Pits Love Against Diseas
#
#                                        genres                languages  \
# 0    'Drama', 'Mystery', 'Thriller', 'Horror'                'Spanish'
# 1
# 2                          'Drama', 'Romance'      'English', 'French'
# 3                         'Romance', 'Comedy'  'English', 'Vietnamese'
# 4                           'Drama', 'Comedy'      'French', 'English'
# ..                                        ...                      ...
# 185
# 186
# 187                                  'Comedy'                 'French'
# 188
# 189
#
#                        production_country
# 0                             'Argentina'
# 1
# 2    'Canada', 'United States of America'
# 3              'United States of America'
# 4                                'France'
# ..                                    ...
# 185
# 186
# 187                   'Belgium', 'France'
# 188
# 189
#
# [190 rows x 21 columns]

# %%
# Drop "byline.person" column
combined_df = combined_df.drop("byline.person", axis=1)

# %%
# Delete duplicate rows and reset index
combined_df = combined_df.drop_duplicates(keep = False)
combined_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 185  https://www.nytimes.com/2017/06/22/movies/my-j...
# 186  https://www.nytimes.com/2017/06/22/movies/the-...
# 187  https://www.nytimes.com/2017/06/15/movies/lost...
# 188  https://www.nytimes.com/2017/06/01/movies/vinc...
# 189  https://www.nytimes.com/2017/05/18/movies/ever...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 185  In “My Journey Through French Cinema,” Mr. Tav...  The New York Times
# 186  Kumail Nanjiani stars opposite Zoe Kazan in th...  The New York Times
# 187  The filmmakers Fiona Gordon and Dominique Abel...  The New York Times
# 188  This combination crime drama and romance finds...  The New York Times
# 189  Amandla Stenberg plays a teenager with an immu...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 185  subject: Documentary Films and Programs;person...
# 186  subject: Movies;creative_works: The Big Sick (...
# 187  creative_works: Lost in Paris (Movie);subject:...
# 188  subject: Movies;creative_works: Vincent N Roxx...
# 189  subject: Movies;creative_works: Everything, Ev...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 185  2017-06-22T21:14:56+0000         773
# 186  2017-06-22T09:00:31+0000        1073
# 187  2017-06-15T19:37:09+0000         254
# 188  2017-06-01T19:52:51+0000         287
# 189  2017-05-18T21:02:53+0000         270
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 185  Review: Those Movies, Himself — Bertrand Taver...            None
# 186  Review: In ‘The Big Sick,’ Comedy Is Hard, Lov...            None
# 187  Review: Finding Love (and Slapstick) While ‘Lo...            None
# 188  Review: In ‘Vincent N Roxxy,’ Love Is in the A...            None
# 189  Review: ‘Everything, Everything’ Pits Love Aga...            None
#
#     headline.content_kicker                 headline.print_headline  \
# 0                      None                  The Attachment Diaries
# 1                      None          What’s Love Got to Do With It?
# 2                      None                    You Can Live Forever
# 3                      None              A Tourist’s  Guide to Love
# 4                      None  Intoxicating Love With a Sobering Turn
# ..                      ...                                     ...
# 185                    None           Reflecting on a Lifelong Love
# 186                    None                 Love and (Almost) Death
# 187                    None                           Lost in Paris
# 188                    None                         Vincent N Roxxy
# 189                    None                  Everything, Everything
#
#     headline.name headline.seo headline.sub           byline.original  \
# 0            None         None         None    By Jeannette Catsoulis
# 1            None         None         None    By Jeannette Catsoulis
# 2            None         None         None  By Elisabeth Vincentelli
# 3            None         None         None  By Elisabeth Vincentelli
# 4            None         None         None         By Manohla Dargis
# ..            ...          ...          ...                       ...
# 185          None         None         None         By Manohla Dargis
# 186          None         None         None         By Manohla Dargis
# 187          None         None         None         By Ben Kenigsberg
# 188          None         None         None         By Ken Jaworowski
# 189          None         None         None        By Neil Genzlinger
#
#     byline.organization                                              title  \
# 0                  None                             The Attachment Diaries
# 1                  None      What’s Love Got to Do With It?’ Probably a Lo
# 2                  None                               You Can Live Forever
# 3                  None                          A Tourist’s Guide to Love
# 4                  None                            Other People’s Children
# ..                  ...                                                ...
# 185                None  Review: Those Movies, Himself — Bertrand Taver...
# 186                None          The Big Sick,’ Comedy Is Hard, Love Harde
# 187                None                                      Lost in Paris
# 188                None  Vincent N Roxxy,’ Love Is in the Air, N So Is Fea
# 189                None   Everything, Everything’ Pits Love Against Diseas
#
#     movie_id                                    genres  \
# 0     743040  'Drama', 'Mystery', 'Thriller', 'Horror'
# 1
# 2     887580                        'Drama', 'Romance'
# 3     813726                       'Romance', 'Comedy'
# 4     803694                         'Drama', 'Comedy'
# ..       ...                                       ...
# 185
# 186
# 187   413778                                  'Comedy'
# 188
# 189
#
#                    languages                    production_country
# 0                  'Spanish'                           'Argentina'
# 1
# 2        'English', 'French'  'Canada', 'United States of America'
# 3    'English', 'Vietnamese'            'United States of America'
# 4        'French', 'English'                              'France'
# ..                       ...                                   ...
# 185
# 186
# 187                 'French'                   'Belgium', 'France'
# 188
# 189
#
# [190 rows x 20 columns]

# %%
# Export data to CSV without the index
combined_df.to_csv("Movie_output_from_combined_API_data.csv", index=False)
